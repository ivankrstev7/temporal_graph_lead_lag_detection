# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/CongWeilin/GraphMixer.git
# Out:
# Cloning into 'GraphMixer'...
# remote: Enumerating objects: 99, done.
# remote: Counting objects: 100% (99/99), done.
# remote: Compressing objects: 100% (76/76), done.
# remote: Total 99 (delta 49), reused 67 (delta 20), pack-reused 0 (from 0)
# Receiving objects: 100% (99/99), 35.94 KiB | 2.25 MiB/s, done.
# Resolving deltas: 100% (49/49), done.

# %%
import torch
print(torch.__version__)
print(torch.cuda.is_available())
print(torch.version.cuda)
# Out:
# 2.5.1+cu121
# True
# 12.1

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2023 NVIDIA Corporation
# Built on Tue_Aug_15_22:02:13_PDT_2023
# Cuda compilation tools, release 12.2, V12.2.140
# Build cuda_12.2.r12.2/compiler.33191640_0

# %%
# !pip install torch==2.4.0 torchvision==0.19.0 torchaudio==2.4.0 --index-url https://download.pytorch.org/whl/cu121
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu121
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 799.1/799.1 MB 1.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 98.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 83.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 79.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 51.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 87.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 7.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 13.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 7.9 MB/s eta 0:00:00
# ...

# %%
import torch
print(torch.__version__)
# Out:
# 2.4.0+cu121

# %%
# pytorch

# pytorch-geometric
# !pip install --verbose torch-scatter torch-sparse torch-cluster torch-spline-conv torch-geometric -f https://data.pyg.org/whl/torch-{torch.__version__}.html

# pybind11 (used for c++ sampler)
# !pip install pybind11
# Out:
# Using pip 24.1.2 from /usr/local/lib/python3.11/dist-packages/pip (python 3.11)
# Looking in links: https://data.pyg.org/whl/torch-2.4.0+cu121.html
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 54.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 38.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 66.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 989.8/989.8 kB 33.8 MB/s eta 0:00:00
# ...
#   Obtaining dependency information for torch-geometric from https://files.pythonhosted.org/packages/03/9f/157e913626c1acfb3b19ce000b1a6e4e4fb177c0bc0ea0c67ca5bd714b5a/torch_geometric-2.6.1-py3-none-any.whl.metadata
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 kB 4.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 23.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 292.1/292.1 kB 18.6 MB/s eta 0:00:00
# ...

# %%
# !cd GraphMixer/DATA && mkdir test
# !mv edges.csv GraphMixer/DATA//test
# !mv node_features.pt GraphMixer/DATA/test
# !mv edge_features.pt GraphMixer/DATA/test

# %%
# %cd GraphMixer
# Out:
# /content/drive/MyDrive/Data Science Padova/Thesis/GraphMixer

# %%
# !python setup.py build_ext --inplace
# Out:
# running build_ext

# %%
# !python gen_graph.py --data leadlag

# %%
# !mkdir results

# %% [markdown]
# # **Positive + Negative**

# %%
# !python train.py --data test   --num_neighbors 1 --neg_samples 1 --use_graph_structure --structure_time_gap 55 --epochs 90 --batch_size 128
# Out:
# Namespace(data='test', device=0, batch_size=128, epochs=90, max_edges=50, lr=0.0001, weight_decay=1e-06, model='mlp_mixer', neg_samples=1, extra_neg_samples=5, num_neighbors=1, sampled_num_hops=1, hidden_dims=100, num_layers=1, regen_models=True, check_data_leakage=False, ignore_node_feats=False, node_feats_as_edge_feats=False, ignore_edge_feats=False, use_onehot_node_feats=False, use_graph_structure=True, structure_time_gap=55, structure_hops=1, use_node_cls=False, use_cached_subgraph=False)
# Train 8686, Valid 373, Test 381
# Num nodes 30, num edges 9440
# ...

# %% [markdown]
# ## **Positive relationships only**

# %%
# !python gen_graph.py --data positive

# %%
# !python train.py --data positive   --num_neighbors 1 --neg_samples 1 --use_graph_structure --structure_time_gap 55 --epochs 90 --batch_size 128
# Out:
# Namespace(data='positive', device=0, batch_size=128, epochs=40, max_edges=50, lr=0.0001, weight_decay=1e-06, model='mlp_mixer', neg_samples=1, extra_neg_samples=5, num_neighbors=5, sampled_num_hops=1, hidden_dims=100, num_layers=1, regen_models=True, check_data_leakage=False, ignore_node_feats=False, node_feats_as_edge_feats=False, ignore_edge_feats=False, use_onehot_node_feats=False, use_graph_structure=True, structure_time_gap=55, structure_hops=1, use_node_cls=False, use_cached_subgraph=False)
# Train 2330, Valid 169, Test 105
# Num nodes 30, num edges 2604
# ...

# %% [markdown]
# # **Temporal Node Features**

# %%
# !python train.py --data test   --num_neighbors 5 --neg_samples 1 --node_feats_as_edge_feats --use_graph_structure --structure_time_gap 55 --epochs 90 --batch_size 128
# best results so far with temporal node features (only price), using node features as edge fratures
# Out:
# Namespace(data='test', device=0, batch_size=128, epochs=90, max_edges=50, lr=0.0001, weight_decay=1e-06, model='mlp_mixer', neg_samples=1, extra_neg_samples=5, num_neighbors=1, sampled_num_hops=1, hidden_dims=100, num_layers=1, regen_models=True, check_data_leakage=False, ignore_node_feats=False, node_feats_as_edge_feats=True, ignore_edge_feats=False, use_onehot_node_feats=False, use_graph_structure=True, structure_time_gap=55, structure_hops=1, use_node_cls=False, use_cached_subgraph=False)
# Train 8686, Valid 373, Test 381
# Num nodes 30, num edges 9440
# ...

# %% [markdown]
# ## **GM-TNF: positive only**

# %%
# !python gen_graph.py --data positive

# %%
# !python train.py --data test   --num_neighbors 5 --neg_samples 1 --node_feats_as_edge_feats --use_graph_structure --structure_time_gap 55 --epochs 90 --batch_size 128
# Out:
# Namespace(data='test', device=0, batch_size=128, epochs=20, max_edges=50, lr=0.0001, weight_decay=1e-06, model='mlp_mixer', neg_samples=1, extra_neg_samples=5, num_neighbors=5, sampled_num_hops=1, hidden_dims=100, num_layers=1, regen_models=True, check_data_leakage=False, ignore_node_feats=False, node_feats_as_edge_feats=True, ignore_edge_feats=False, use_onehot_node_feats=False, use_graph_structure=True, structure_time_gap=55, structure_hops=1, use_node_cls=False, use_cached_subgraph=False)
# Train 8686, Valid 373, Test 381
# Num nodes 30, num edges 9440
# ...
